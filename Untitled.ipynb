# %%
# !pip install scattertext
# !pip install ginza
# !pip install neologdn
# Out:
# Collecting scattertext
#   Downloading scattertext-0.1.6-py3-none-any.whl (7.3 MB)
#      |████████████████████████████████| 7.3 MB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/devekawa/anaconda3/lib/python3.8/site-packages (from scattertext) (1.20.3)
# Collecting flashtext
#   Downloading flashtext-2.7.tar.gz (14 kB)
# Requirement already satisfied: six in /home/devekawa/anaconda3/lib/python3.8/site-packages (from scattertext) (1.16.0)
# Requirement already satisfied: gensim>=4.0.0 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from scattertext) (4.0.1)
# Requirement already satisfied: scipy in /home/devekawa/anaconda3/lib/python3.8/site-packages (from scattertext) (1.7.1)
# Requirement already satisfied: mock in /home/devekawa/anaconda3/lib/python3.8/site-packages (from scattertext) (4.0.3)
# Requirement already satisfied: pandas in /home/devekawa/anaconda3/lib/python3.8/site-packages (from scattertext) (1.2.5)
# Requirement already satisfied: statsmodels in /home/devekawa/anaconda3/lib/python3.8/site-packages (from scattertext) (0.12.2)
# Requirement already satisfied: scikit-learn in /home/devekawa/anaconda3/lib/python3.8/site-packages (from scattertext) (1.0.1)
# Requirement already satisfied: smart-open>=1.8.1 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from gensim>=4.0.0->scattertext) (5.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from pandas->scattertext) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from pandas->scattertext) (2021.3)
# Requirement already satisfied: joblib>=0.11 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from scikit-learn->scattertext) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from scikit-learn->scattertext) (2.2.0)
# Requirement already satisfied: patsy>=0.5 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from statsmodels->scattertext) (0.5.2)
# Building wheels for collected packages: flashtext
#   Building wheel for flashtext (setup.py) ... done
#   Created wheel for flashtext: filename=flashtext-2.7-py2.py3-none-any.whl size=9310 sha256=333f6b90b39b81827f6b8c5a97300f46fc6f362fe0a5d42cfa9e8a98303a6964
#   Stored in directory: /home/devekawa/.cache/pip/wheels/8d/62/8b/71813348245ae1bcbae179193bbc72db819e8057e89298a6ac
# Successfully built flashtext
# Installing collected packages: flashtext, scattertext
# Successfully installed flashtext-2.7 scattertext-0.1.6
# Collecting ginza
#   Downloading ginza-5.1.1-py3-none-any.whl (20 kB)
# Collecting plac>=1.3.3
#   Downloading plac-1.3.5-py2.py3-none-any.whl (22 kB)
# Collecting SudachiPy<0.7.0,>=0.6.2
#   Downloading SudachiPy-0.6.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 3.4 MB/s eta 0:00:01     |███████████████████████████████▌| 2.2 MB 3.4 MB/s eta 0:00:01
# Collecting SudachiDict-core>=20210802
#   Downloading SudachiDict-core-20211220.tar.gz (9.1 kB)
# Collecting spacy<3.3.0,>=3.2.0
#   Downloading spacy-3.2.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 24 kB/s s eta 0:00:01
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.6-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 24.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15.0 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->ginza) (1.20.3)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36 kB)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#      |████████████████████████████████| 459 kB 21.4 MB/s eta 0:00:01
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp38-cp38-manylinux2014_x86_64.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 35 kB/s s eta 0:00:01     |█████████████████████████████▍  | 12.6 MB 25.6 MB/s eta 0:00:01
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 21.4 MB/s eta 0:00:01
# Requirement already satisfied: jinja2 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->ginza) (2.11.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->ginza) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->ginza) (21.3)
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.9.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: setuptools in /home/devekawa/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->ginza) (58.0.4)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.15-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (663 kB)
#      |████████████████████████████████| 663 kB 24.0 MB/s eta 0:00:01
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 250 kB/s  eta 0:00:01
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.1-py3-none-any.whl (27 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.2-py3-none-any.whl (7.2 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 25.4 MB/s eta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.6-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.7-py3-none-any.whl (17 kB)
# Requirement already satisfied: click<8.1.0 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->ginza) (7.1.2)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->ginza) (2.26.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->ginza) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->ginza) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->ginza) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->ginza) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->ginza) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->ginza) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->ginza) (1.26.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/devekawa/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->ginza) (2.0.1)
# Building wheels for collected packages: SudachiDict-core
#   Building wheel for SudachiDict-core (setup.py) ... done
#   Created wheel for SudachiDict-core: filename=SudachiDict_core-20211220-py3-none-any.whl size=71565352 sha256=035a43c8faa76f1be9d0985f1c6e72ee8b185b4c06b505134f3c88f597185d82
#   Stored in directory: /home/devekawa/.cache/pip/wheels/01/b5/b9/a18f424b45892ca02ca5762b844ad49be1f638e913e8e625fa
# Successfully built SudachiDict-core
# Installing collected packages: murmurhash, cymem, catalogue, wasabi, typer, srsly, pydantic, preshed, blis, thinc, SudachiPy, spacy-loggers, spacy-legacy, pathy, langcodes, SudachiDict-core, spacy, plac, ginza
# Successfully installed SudachiDict-core-20211220 SudachiPy-0.6.3 blis-0.7.7 catalogue-2.0.7 cymem-2.0.6 ginza-5.1.1 langcodes-3.3.0 murmurhash-1.0.6 pathy-0.6.1 plac-1.3.5 preshed-3.0.6 pydantic-1.8.2 spacy-3.2.4 spacy-legacy-3.0.9 spacy-loggers-1.0.2 srsly-2.4.3 thinc-8.0.15 typer-0.4.1 wasabi-0.9.1
# Collecting neologdn
#   Downloading neologdn-0.5.1.tar.gz (57 kB)
#      |████████████████████████████████| 57 kB 627 kB/s eta 0:00:011
# Building wheels for collected packages: neologdn
#   Building wheel for neologdn (setup.py) ... done
#   Created wheel for neologdn: filename=neologdn-0.5.1-cp38-cp38-linux_x86_64.whl size=184344 sha256=1041edd91e843461f787830685a0931210ebcb4f71e44dd01f8850b01b3bb62a
#   Stored in directory: /home/devekawa/.cache/pip/wheels/3e/db/10/b3b26caa63c5da86ea3a25043cc4379a66bb3dd30d6f060a37
# Successfully built neologdn
# Installing collected packages: neologdn
# Successfully installed neologdn-0.5.1

# %%
# GiNZAを使用するためのおまじない
import pkg_resources, imp
imp.reload(pkg_resources)

import pandas
import scattertext as st
import spacy
from collections import Counter
from itertools import chain
from IPython.display import HTML

import glob
import os
import pathlib
import tarfile
import neologdn
import pandas as pd

# Livedoorニュースのファイルをダウンロード
! wget "https://www.rondhuit.com/download/ldcc-20140209.tar.gz"

# rawデータ解凍
tar = tarfile.open("./ldcc-20140209.tar.gz", "r:gz")
tar.extractall(".")
tar.close()

# Dataframeの作成
df = pd.DataFrame(columns=["text", "category"])

for file_path in pathlib.Path("./text").glob("**/*.txt"):
    f_path = pathlib.Path(file_path)
    file_name = f_path.name
    category_name = f_path.parent.name

    if category_name in ['movie-enter', 'sports-watch']:

        # 特殊ファイルはスキップ
        if file_name in ["CHANGES.txt", "README.txt", "LICENSE.txt"]:
            continue

        with open(file_path, "r") as f:
            text_all = f.read()
            text_lines = text_all.split("\n")
            url, time, title, *text = text_lines

            # text前処理
            text = "".join(text)
            text = text.strip()
            text = neologdn.normalize(text)
            text = text.replace(' ', '')
            text = text.replace('　', '')

            df.loc[file_name] = [text,category_name]

# インデックスに使用していたファイル名を削除
df.reset_index(inplace=True,drop=True)



# 品詞を絞りこみつつ、unigramの出現回数を集計
class UnigramSelectedPos(st.FeatsFromSpacyDoc):
    """
    品詞の絞り込みを行い、unigramをカウント
    デフォルトの絞り込み品詞は[固有名詞、名詞、動詞、形容詞、副詞]
    """    
    def __init__(self,use_pos=['PROPN', 'NOUN', 'VERB', 'ADJ', 'ADV']):
        super().__init__()
        self._use_pos = use_pos

    def get_feats(self, doc):
        return Counter([c.lemma_ for c in doc if c.pos_ in self._use_pos])

# Corpusの作成
corpus = (st.CorpusFromPandas(df, 
                              category_col='category', 
                              text_col='text',
                              nlp = spacy.load("ja_ginza"),
                              feats_from_spacy_doc=UnigramSelectedPos()
                              )
          .build())
          
html = st.produce_scattertext_explorer(
          corpus,
          category='sports-watch', # y軸カテゴリ
          not_categories = ['movie-enter'], # x軸カテゴリ（複数選択可）
          category_name='Sports Watch', # y軸ラベル
          not_category_name='MOVIE ENTER', # x軸ラベル
          asian_mode=True, # 日本語モード
          minimum_term_frequency=50, # 指定より出現回数の多い単語のみをプロット
          max_terms=4000 # プロットする最大数
          )

# 散布図の表示
# Out:
# --2022-04-22 16:35:26--  https://www.rondhuit.com/download/ldcc-20140209.tar.gz
# www.rondhuit.com (www.rondhuit.com) をDNSに問いあわせています... 59.106.19.174
# www.rondhuit.com (www.rondhuit.com)|59.106.19.174|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 200 OK
# 長さ: 8855190 (8.4M) [application/x-gzip]
# `ldcc-20140209.tar.gz' に保存中
#
# ldcc-20140209.tar.g 100%[===================>]   8.44M  10.5MB/s    時間 0.8s
#
# 2022-04-22 16:35:27 (10.5 MB/s) - `ldcc-20140209.tar.gz' へ保存完了 [8855190/8855190]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_16721/1139759793.py in <module>
#      75                               category_col='category',
#      76                               text_col='text',
# ---> 77                               nlp = spacy.load("ja_ginza"),
#      78                               feats_from_spacy_doc=UnigramSelectedPos()
#      79                               )
#
# ~/anaconda3/lib/python3.8/site-packages/spacy/__init__.py in load(name, vocab, disable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# ~/anaconda3/lib/python3.8/site-packages/spacy/util.py in load_model(name, vocab, disable, exclude, config)
#     425     if name in OLD_MODEL_SHORTCUTS:
#     426         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 427     raise IOError(Errors.E050.format(name=name))
#     428
#     429
#
# OSError: [E050] Can't find model 'ja_ginza'. It doesn't seem to be a Python package or a valid path to a data directory.
